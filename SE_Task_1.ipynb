# %%
import matplotlib.pyplot as plt
import numpy as np
def quadratic_model(time):
  a=0.56
  b=-8
  c=70

  temperature = a*(time**2)+b*time+c
  return temperature

def main():
  time_values = np.linspace(0,10,50)


  temperature_hardcoded = quadratic_model(time_values)

  plt.plot(time_values,temperature_hardcoded,label='Hard-coded Coefficients\n a = 0.56, b = -8, c = 70')
  plt.xlabel('Time')
  plt.ylabel('Temperature')
  plt.legend()
  plt.title('Weather modelling with Quadratic equation(hard-coded coefficient)')
  plt.show()
if_name_="main"
main()

# %%
import matplotlib.pyplot as plt
import numpy as np
def quadratic_model(time,a,b,c):

  temperature = a*(time**2)+b*time+c
  return temperature
def main():
  time_values = np.linspace(0,10,50)
  a=float(input("enter the value of a:"))
  b=float(input("enter the value of b:"))
  c=float(input("enter the value of c:"))
  temperature_hardcoded = quadratic_model(time_values,a,b,c)
  plt.plot(time_values,temperature_hardcoded,label=f'keyboard input Coefficients\n a = {a}, b = {b}, c = {c}')
  plt.xlabel('Time')
  plt.ylabel('Temperature')
  plt.legend()
  plt.title('Weather modelling with Quadratic equation(keyboard input coefficient)')
  plt.show()
if_name_="main"
main()
# Out:
# enter the value of a:7
# enter the value of b:-2
# enter the value of c:6

# %%
import numpy as np

def quadratic_model(time, a, b, c):
    temperature = a * (time ** 2) + b * time + c
    return temperature

def read_coefficients_from_file(filename):
    with open(filename, 'r') as f:
        coefficients = [float(line.strip()) for line in f]
    return coefficients

def main():
    time_values = np.linspace(0, 10, 50)

    try:
        coefficients = read_coefficients_from_file('coefficients.txt')
        if len(coefficients) != 3:
            raise ValueError("The coefficients file should contain exactly three lines.")
        a, b, c = coefficients
    except FileNotFoundError:
        print("Error: coefficients.txt not found.")
        return
    except ValueError as e:
        print(f"Error: {e}")
        return

    temperature_from_file = quadratic_model(time_values, a, b, c)

    plt.plot(time_values, temperature_from_file, label=f'Coefficients from File\n a = {a}, b = {b}, c = {c}')
    plt.xlabel('Time')
    plt.ylabel('Temperature')
    plt.legend()
    plt.title('Weather Modelling with Quadratic Equation (Coefficients from File)')
    plt.show()

if __name__ == "__main__":
    main()

# %%
import matplotlib.pyplot as plt
import numpy as np

def quadratic_model(time, a, b, c):
    temperature = a * (time ** 2) + b * time + c
    return temperature

def main():
    time_values = np.linspace(0, 10, 50)

    coeffs = [4, 7, -9]

    a, b, c = coeffs
    temperature_values = quadratic_model(time_values, a, b, c)

    label = f'Coefficients Set\n a = {a}, b = {b}, c = {c}'

    plt.plot(time_values, temperature_values, label=label)

    plt.xlabel('Time')
    plt.ylabel('Temperature')
    plt.legend()
    plt.title('Weather Modelling with Quadratic Equation - Single Input')
    plt.grid(True)
    plt.show()

if __name__ == "__main__":
    main()

# %%
import matplotlib.pyplot as plt
import numpy as np

def quadratic_model(time, a, b, c):
    temperature = a * (time ** 2) + b * time + c
    return temperature

def main():
    time_values = np.linspace(0, 10, 50)

    parameters_sets = [
        {'a': 5.0, 'b': 4.0, 'c': -2.0},
        {'a': 7.9, 'b': 2.0, 'c': -1.1},
        {'a': -5.2, 'b': 6.6, 'c': 5.9}
    ]

    for params in parameters_sets:
        a = params['a']
        b = params['b']
        c = params['c']

        temperature_calculated = quadratic_model(time_values, a, b, c)

        plt.plot(time_values, temperature_calculated, label=f'a={a}, b={b}, c={c}')

    plt.xlabel('Time')
    plt.ylabel('Temperature')
    plt.legend()
    plt.title('Weather Modelling with Quadratic Equation (Multiple Lines)')
    plt.show()

if __name__ == "__main__":
    main()

# %%
import matplotlib.pyplot as plt
import numpy as np

def quadratic_model(time, a, b, c):
    temperature = a * (time**2) + b * time + c
    return temperature

def main():
    time_values = np.linspace(0, 10, 50)

    a_hardcoded = 1
    b_hardcoded = -2
    c_hardcoded = 5

    a_user = float(input("Enter the value of a: "))
    b_user = float(input("Enter the value of b: "))
    c_user = float(input("Enter the value of c: "))

    temperature_hardcoded = quadratic_model(time_values, a_hardcoded, b_hardcoded, c_hardcoded)
    temperature_user = quadratic_model(time_values, a_user, b_user, c_user)

    plt.plot(time_values, temperature_hardcoded, label=f'Hardcoded Coefficients: a = 1, b = -2, c = 5')
    plt.plot(time_values, temperature_user, label=f'User Input Coefficients a = {a_user}, b = {b_user}, c = {c_user}', linestyle='--')

    plt.xlabel('Time')
    plt.ylabel('Temperature')
    plt.legend()
    plt.title('Weather Modelling with Quadratic Equation')
    plt.show()

if __name__ == "__main__":
    main()
# Out:
# Enter the value of a: 6
# Enter the value of b: 9
# Enter the value of c: 10

# %%
import matplotlib.pyplot as plt
import numpy as np

def quadratic_model(time, a, b, c):
    temperature = a * (time ** 2) + b * time + c
    return temperature

def main():
    time_values = np.linspace(0, 10, 50)

    with open('parameters.txt', 'r') as file:
        for line in file:
            a, b, c = map(float, line.strip().split())

            temperature_calculated = quadratic_model(time_values, a, b, c)

            plt.plot(time_values, temperature_calculated, label=f'a={a}, b={b}, c={c}')

    plt.xlabel('Time')
    plt.ylabel('Temperature')
    plt.legend()
    plt.title('Weather Modelling with Quadratic Equation Multiple (File Input)')
    plt.show()

if __name__ == "__main__":
    main()
